# %%
# Import 需要的套件
import os
import numpy as np
import pandas as pd

# 設定 data_path
dir_data = './data/'

# %%
f_app_train = os.path.join(dir_data, 'application_train.csv')
app_train = pd.read_csv(f_app_train)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 練習時間

# %% [markdown]
# 觀察有興趣的欄位的資料分佈，並嘗試找出有趣的訊息
# #### Eg
# - 計算任意欄位的平均數及標準差
# - 畫出任意欄位的[直方圖](https://zh.wikipedia.org/zh-tw/%E7%9B%B4%E6%96%B9%E5%9B%BE)
#
# ### Hints:
# - [Descriptive Statistics For pandas Dataframe](https://chrisalbon.com/python/data_wrangling/pandas_dataframe_descriptive_stats/)
# - [pandas 中的繪圖函數](https://amaozhao.gitbooks.io/pandas-notebook/content/pandas%E4%B8%AD%E7%9A%84%E7%BB%98%E5%9B%BE%E5%87%BD%E6%95%B0.html)

# %%
app_train[10:20]
# Out:
#     SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 10      100014       0         Cash loans           F            N
# 11      100015       0         Cash loans           F            N
# 12      100016       0         Cash loans           F            N
# 13      100017       0         Cash loans           M            Y
# 14      100018       0         Cash loans           F            N
# 15      100019       0         Cash loans           M            Y
# 16      100020       0         Cash loans           M            N
# 17      100021       0    Revolving loans           F            N
# 18      100022       0    Revolving loans           F            N
# 19      100023       0         Cash loans           F            N
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 10               Y             1        112500.000    652500.0      21177.0
# ...

# %%
app_train.shape
# Out:
# (307511, 122)

# %%
app_train['AMT_ANNUITY'].idxmin() #最小值的位置
app_train['AMT_ANNUITY'].idxmax() #最大值的位置
# Out:
# 17948

# %%
app_train['AMT_ANNUITY'].sum()
# Out:
# 8335859368.5

# %%
sum(pd.isnull(app_train['AMT_ANNUITY'])) #缺失值數量
# Out:
# 12

# %%
app_train['AMT_ANNUITY'].describe()       #一次性输出多个描述性统计指标

# 原文：https://blog.csdn.net/A632189007/article/details/76176985
# Out:
# count    307499.000000
# mean      27108.573909
# std       14493.737315
# min        1615.500000
# 25%       16524.000000
# 50%       24903.000000
# 75%       34596.000000
# max      258025.500000
# Name: AMT_ANNUITY, dtype: float64

# %%
plt.hist(app_train['AMT_ANNUITY'])
plt.show()
# Out:
# c:\program files (x86)\python37-32\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# c:\program files (x86)\python37-32\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
app_train[10:20].fillna(0)
# (method='ffill')   用前一个值填充
# (method='ffill')   用前一个值填充
# Out:
#     SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 10      100014       0         Cash loans           F            N
# 11      100015       0         Cash loans           F            N
# 12      100016       0         Cash loans           F            N
# 13      100017       0         Cash loans           M            Y
# 14      100018       0         Cash loans           F            N
# 15      100019       0         Cash loans           M            Y
# 16      100020       0         Cash loans           M            N
# 17      100021       0    Revolving loans           F            N
# 18      100022       0    Revolving loans           F            N
# 19      100023       0         Cash loans           F            N
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 10               Y             1        112500.000    652500.0      21177.0
# ...

# %%
app_train.dropna().shape #该操作会删除所有有缺失值的行数据
# Out:
# (8602, 122)

# %%
app_train_drop = app_train.dropna()
app_train_drop['AMT_ANNUITY'].describe()
# Out:
# count      8602.000000
# mean      31558.948326
# std       16587.353415
# min        2317.500000
# 25%       19548.000000
# 50%       29209.500000
# 75%       40320.000000
# max      225000.000000
# Name: AMT_ANNUITY, dtype: float64

# %%
plt.hist(app_train_drop['AMT_ANNUITY'])
plt.show()
