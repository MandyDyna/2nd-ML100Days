# %% [markdown]
# # 作業重點
#
# 使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

# %% [markdown]
# # 作業目標:
#     請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#     lr = [0.1, 0.0001]
#     主要驗證 Lr 對於grandient 收斂的速度

# %%
cur_x = 3 # The algorithm starts at x=3
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 10000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function

# %%
#需要執行初始值設定, 下列三個
lr = [0.1, 0.0001] # Learning rate
iters = 0 # iteration counter
previous_step_size = 1 # Step size

# %%
lr_history=[]
iters_history = [iters]
x_history = [cur_x]

# %%
while previous_step_size > precision and iters < max_iters:
    prev_x = cur_x #Store current x value in prev_x
    cur_x = cur_x - lr[0] * df(prev_x) #Gradient descent
    previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x
    iters = iters+1 #iteration count
    print("Iteration",iters,"\nX value is",cur_x)
    if iters > 10:
        #prev_x = cur_x #Store current x value in prev_x
        cur_x = cur_x - lr[1] * df(prev_x) #Gradient descent
        previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x
        iters = iters+1 #iteration count
        print("Iteration",iters,"\nX value is",cur_x)
    
    lr_history.append(lr)
    iters_history.append(iters)
    x_history.append(cur_x)
    #算法迭代更新
# Out:
# Iteration 1
# X value is 1.4
# Iteration 2
# X value is 0.11999999999999966
# Iteration 3
# X value is -0.9040000000000001
# Iteration 4
# X value is -1.7232000000000003
# Iteration 5
# X value is -2.3785600000000002
# Iteration 6
# X value is -2.902848
# Iteration 7
# X value is -3.3222784
# Iteration 8
# X value is -3.65782272
# Iteration 9
# X value is -3.926258176
# Iteration 10
# X value is -4.1410065408
# Iteration 11
# X value is -4.312805232640001
# Iteration 12
# X value is -4.31297703133184
# Iteration 13
# X value is -4.450381625065472
# Iteration 14
# X value is -4.450519029659206
# Iteration 15
# X value is -4.5604152237273645
# Iteration 16
# X value is -4.560525119921433
# Iteration 17
# X value is -4.648420095937146
# Iteration 18
# X value is -4.648507990913162
# Iteration 19
# X value is -4.71880639273053
# Iteration 20
# X value is -4.718876691132347
# Iteration 21
# X value is -4.775101352905877
# Iteration 22
# X value is -4.775157577567651
# Iteration 23
# X value is -4.82012606205412
# Iteration 24
# X value is -4.8201710305386065
# Iteration 25
# X value is -4.856136824430886
# Iteration 26
# X value is -4.856172790224778
# Iteration 27
# X value is -4.884938232179822
# Iteration 28
# X value is -4.884966997621777
# Iteration 29
# X value is -4.9079735980974215
# Iteration 30
# X value is -4.907996604697897
# Iteration 31
# X value is -4.926397283758318
# Iteration 32
# X value is -4.926415684437378
# Iteration 33
# X value is -4.941132547549903
# Iteration 34
# X value is -4.941147264413015
# Iteration 35
# X value is -4.952917811530412
# Iteration 36
# X value is -4.952929582077529
# Iteration 37
# X value is -4.962343665662024
# Iteration 38
# X value is -4.962353079745609
# Iteration 39
# X value is -4.969882463796487
# Iteration 40
# X value is -4.969889993180537
# Iteration 41
# X value is -4.97591199454443
# Iteration 42
# X value is -4.975918016545794
# Iteration 43
# X value is -4.980734413236635
# Iteration 44
# X value is -4.980739229633326
# Iteration 45
# X value is -4.984591383706661
# Iteration 46
# X value is -4.984595235860734
# Iteration 47
# X value is -4.987676188688587
# Iteration 48
# X value is -4.987679269641415
# Iteration 49
# X value is -4.990143415713132
# Iteration 50
# X value is -4.990145879859204
# Iteration 51
# X value is -4.992116703887364
# Iteration 52
# X value is -4.992118674711392
# Iteration 53
# X value is -4.993694939769114
# Iteration 54
# X value is -4.993696516034172
# Iteration 55
# X value is -4.994957212827337
# Iteration 56
# X value is -4.994958473524131
# Iteration 57
# X value is -4.995966778819304
# Iteration 58
# X value is -4.9959677871245995
# Iteration 59
# X value is -4.99677422969968
# Iteration 60
# X value is -4.996775036142255
# Iteration 61
# X value is -4.997420028913804
# Iteration 62
# X value is -4.997420673906575
# Iteration 63
# X value is -4.99793653912526
# Iteration 64
# X value is -4.997937054990479
# Iteration 65
# X value is -4.998349643992383
# Iteration 66
# X value is -4.998350056581385
# Iteration 67
# X value is -4.998680045265108
# Iteration 68
# X value is -4.998680375253792
# Iteration 69
# X value is -4.998944300203034
# Iteration 70
# X value is -4.998944564127983
# Iteration 71
# X value is -4.999155651302386
# Iteration 72
# X value is -4.999155862389561
# Iteration 73
# X value is -4.999324689911648
# Iteration 74
# X value is -4.99932485873917
# Iteration 75
# X value is -4.999459886991336
# Iteration 76
# X value is -4.999460022019589
# Iteration 77
# X value is -4.999568017615671
# Iteration 78
# X value is -4.999568125611267
# Iteration 79
# X value is -4.999654500489013
# Iteration 80
# X value is -4.999654586863891
# Iteration 81
# X value is -4.999723669491113
# Iteration 82
# X value is -4.99972373857374
# Iteration 83
# X value is -4.999778990858992
# Iteration 84
# X value is -4.999779046111278
# Iteration 85
# X value is -4.999823236889022
# Iteration 86
# X value is -4.9998232810798005
# Iteration 87
# X value is -4.99985862486384
# Iteration 88
# X value is -4.999858660207624
# Iteration 89
# X value is -4.9998869281661
# Iteration 90
# X value is -4.999886956434058
# Iteration 91
# X value is -4.999909565147247
# Iteration 92
# X value is -4.99990958775596
# Iteration 93
# X value is -4.999927670204768
# Iteration 94
# X value is -4.999927688287216
# Iteration 95
# X value is -4.9999421506297725
# Iteration 96
# X value is -4.999942165092115
# Iteration 97
# X value is -4.999953732073692
# Iteration 98
# X value is -4.999953743640673
# Iteration 99
# X value is -4.999962994912538
# Iteration 100
# X value is -4.99996300416381
# Iteration 101
# X value is -4.999970403331048
# Iteration 102
# X value is -4.999970410730215
# Iteration 103
# X value is -4.9999763285841725
# Iteration 104
# X value is -4.999976334502026
# Iteration 105
# X value is -4.999981067601621
# Iteration 106
# X value is -4.9999810723347204
# Iteration 107
# X value is -4.999984857867776
# Iteration 108
# X value is -4.999984861653309
# Iteration 109
# X value is -4.9999878893226475
# Iteration 110
# X value is -4.999987892350317
# Iteration 111
# X value is -4.999990313880254
# Iteration 112
# X value is -4.999990316301783
# Iteration 113
# X value is -4.999992253041427
# Iteration 114
# X value is -4.999992254978166
# Iteration 115
# X value is -4.999993803982533
# Iteration 116
# X value is -4.999993805531537
# Iteration 117
# X value is -4.99999504442523
# Iteration 118
# X value is -4.999995045664123
# Iteration 119
# X value is -4.999996036531298
# Iteration 120
# X value is -4.999996037522165

# %%
'''
while previous_step_size > precision and iters < max_iters:
    if previous_step_size > 1:
        prev_x = cur_x #Store current x value in prev_x
        cur_x = cur_x - lr[0] * df(prev_x) #Gradient descent
        previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x
        iters = iters+1 #iteration count
        print("Iteration",iters,"\nX value is",cur_x)
    else:
        #prev_x = cur_x #Store current x value in prev_x
        cur_x = cur_x - lr[1] * df(prev_x) #Gradient descent
        previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x
        iters = iters+1 #iteration count
        print("Iteration",iters,"\nX value is",cur_x)
    
    lr_history.append(lr)
    iters_history.append(iters)
    x_history.append(cur_x)
    #算法迭代更新
'''
# Out:
# '\nwhile previous_step_size > precision and iters < max_iters:\n    if previous_step_size > 1:\n        prev_x = cur_x #Store current x value in prev_x\n        cur_x = cur_x - lr[0] * df(prev_x) #Gradient descent\n        previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x\n        iters = iters+1 #iteration count\n        print("Iteration",iters,"\nX value is",cur_x)\n    else:\n        #prev_x = cur_x #Store current x value in prev_x\n        cur_x = cur_x - lr[1] * df(prev_x) #Gradient descent\n        previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x\n        iters = iters+1 #iteration count\n        print("Iteration",iters,"\nX value is",cur_x)\n    \n    lr_history.append(lr)\n    iters_history.append(iters)\n    x_history.append(cur_x)\n    #算法迭代更新\n'

# %%
print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
# Out:
# the learning rate is [0.1, 0.0001]
# Iteration 120
# X value is -4.999996037522165

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
#適用於 Jupyter Notebook, 宣告直接在cell 內印出執行結果

plt.plot(iters_history, x_history, 'o-', ms=3, lw=1.5, color='black')
plt.xlabel(r'$iters$', fontsize=16)
plt.ylabel(r'$x$', fontsize=16)
plt.show()
